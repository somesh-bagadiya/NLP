# %%
import mailbox
import os
from bs4 import BeautifulSoup

# %%
def initialize_output_folder(output_folder):
    os.makedirs(output_folder, exist_ok=True)
    print(f"Output folder created: {output_folder}")

# %%
def open_mbox_file(input_file):
    print("Opening the mbox file...")
    source_mbox = mailbox.mbox(input_file)
    print(f"Total emails in the mbox file: {len(source_mbox)}")
    return source_mbox

# %%
def process_email_body(message):
    try:
        if message.is_multipart():
            parts = []
            for part in message.walk():
                content_type = part.get_content_type()
                content_disposition = str(part.get("Content-Disposition"))
                if content_type == "text/plain" and "attachment" not in content_disposition:
                    parts.append(part.get_payload(decode=True).decode(errors="ignore"))
                elif content_type == "text/html" and "attachment" not in content_disposition:
                    html_body = part.get_payload(decode=True).decode(errors="ignore")
                    soup = BeautifulSoup(html_body, "html.parser")
                    parts.append(soup.get_text(separator="\n").strip())
            return "\n\n".join(parts).strip() if parts else "No Body Content"
        else:
            content_type = message.get_content_type()
            if content_type == "text/plain":
                return message.get_payload(decode=True).decode(errors="ignore").strip()
            elif content_type == "text/html":
                html_body = message.get_payload(decode=True).decode(errors="ignore")
                soup = BeautifulSoup(html_body, "html.parser")
                return soup.get_text(separator="\n").strip()
            else:
                return "Unsupported content type: " + content_type
    except Exception as e:
        print(f"Error processing email body: {e}")
        return "Failed to extract body content."

# %%
def save_email_to_file(email_file, subject, from_email, to_email, date, body):
    try:
        with open(email_file, "w", encoding="utf-8") as f:
            f.write(f"Subject: {subject}\n")
            f.write(f"From: {from_email}\n")
            f.write(f"To: {to_email}\n")
            f.write(f"Date: {date}\n\n")
            f.write(body)
        print(f"  Saved email to {email_file}")
    except Exception as e:
        print(f"Error saving email to file: {e}")

# %%
def process_and_save_emails(source_mbox, output_folder, top_n):
    email_count = 0
    for i, message in enumerate(source_mbox):
        if i >= top_n:
            break
        print(f"Processing email {i + 1}...")
        subject = message['subject'] or "No Subject"
        from_email = message['from'] or "Unknown Sender"
        to_email = message['to'] or "Unknown Recipient"
        date = message['date'] or "Unknown Date"
        print(f"  Subject: {subject}")
        print(f"  From: {from_email}")

        email_file = os.path.join(output_folder, f"email_{i + 1}.txt")
        body = process_email_body(message)
        save_email_to_file(email_file, subject, from_email, to_email, date, body)

        email_count += 1
        if email_count % 10 == 0 or email_count == top_n:
            print(f"Processed {email_count}/{top_n} emails.")

    print(f"Successfully processed and saved {email_count} emails.")

# %%
def save_emails_as_text(input_file, output_folder, top_n=100):
    try:
        print(f"Starting to process the mbox file: {input_file}")
        initialize_output_folder(output_folder)
        source_mbox = open_mbox_file(input_file)
        process_and_save_emails(source_mbox, output_folder, top_n)
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
input_mbox = "All mail Including Spam and Trash.mbox"
output_folder = "data"
save_emails_as_text(input_mbox, output_folder, top_n=5000)
# Out:
# Starting to process the mbox file: All mail Including Spam and Trash.mbox
# Output folder created: data
# Opening the mbox file...
# Total emails in the mbox file: 80072
# Processing email 1...
#   Subject: Gaurav Surtani Sent You a Gift Card for Airbnb
#   From: "Amazon.com Gift Cards" <gc-orders@gc.email.amazon.com>
#   Saved email to data\email_1.txt
# Processing email 2...
#   Subject: Everything on sale & 50% off Doorbusters!
#   From: "Columbia" <email@e-mail.columbia.com>
#   Saved email to data\email_2.txt
# Processing email 3...
#   Subject: Please read: Your dream home is waiting for you.
#   From: SoFi <no-reply@r.sofi.com>
#   Saved email to data\email_3.txt
# Processing email 4...
#   Subject: =?UTF-8?Q?The_future_of_finance_is_here:_D?=
#  =?UTF-8?Q?on=E2=80=99t_miss_'Crypto_ki_Paathshala'?=
#   From: The Economic Times <newsletter@economictimesnews.com>
#   Saved email to data\email_4.txt
# Processing email 5...
#   Subject: =?utf-8?B?VGhlcmUgd29u4oCZdCBiZSBhIGJldHRlciBkZWFsIOKAlCBvbmx5?=
# 	=?utf-8?B?ICQxLjM5L21vbnRo?=
#   From: "Surfshark" <info@mail.surfshark.com>
#   Saved email to data\email_5.txt
# Processing email 6...
#   Subject: Upcoming payment notification: Standing Instructions on your ICICI Bank Credit Card
#   From: cards@icicibank.com
#   Saved email to data\email_6.txt
# Processing email 7...
#   Subject: =?UTF-8?B?R2V0dGluZyAxMDAwIHBvaW50cyBoYXMgbmV2ZXIgYmVlbiBzbyBl?=
#  =?UTF-8?B?YXN5IPCfkrA=?=
#   From: "7-Eleven" <7-eleven@mail.7-eleven.com>
#   Saved email to data\email_7.txt
# Processing email 8...
#   Subject: =?utf-8?Q?New_Video_You=E2=80=99ll_Love_=F0=9F=94=9E:_Check_it_out_now?=
#   From: "=?utf-8?Q?RedGIFs?=" <info@newsletters.redgifs.com>
#   Saved email to data\email_8.txt
# Processing email 9...
#   Subject: Segregation and Monitoring of Collateral at Client Level for
#  02/11/2024 with Zerodha Commodities Pvt Ltd
#   From: inspectioninfo@mcxindia.com
#   Saved email to data\email_9.txt
# Processing email 10...
#   Subject: 13 Python Shortcuts Every Developer Should Use for Faster Coding |
#  Abdur Rahman in Python in Plain English
#   From: Medium Daily Digest <noreply@medium.com>
#   Saved email to data\email_10.txt
# Processed 10/5000 emails.
# Processing email 11...
#   Subject: Join the NJ Knowledge Quiz - 18
#   From: NJ Wealth <info@njwealth.co.in>
#   Saved email to data\email_11.txt
# Processing email 12...
#   Subject: Somesh, don't miss out! Redeem your offers
#   From: "Amex Offers from American Express" <americanexpress@member.americanexpress.com>
#   Saved email to data\email_12.txt
# Processing email 13...
#   Subject: You have an invitation
#   From: Nischal Dinesh <invitations@linkedin.com>
#   Saved email to data\email_13.txt
# Processing email 14...
#   Subject: LTTStore's BFCM 9000 Sale Starts NOW!
#   From: LTTStore <no-reply@lttstore.com>
#   Saved email to data\email_14.txt
# Processing email 15...
#   Subject: NFO now open - HDFC Nifty India Digital Index Fund
#   From: HDFC MF <noresponse@hdfcfund.com>
#   Saved email to data\email_15.txt
# Processing email 16...
#   Subject: 50% off Doorbusters and more Black Friday deals!
#   From: "Columbia" <email@e-mail.columbia.com>
#   Saved email to data\email_16.txt
# Processing email 17...
#   Subject: Somesh, your posts got 173 impressions last week
#   From: LinkedIn <notifications-noreply@linkedin.com>
#   Saved email to data\email_17.txt
# Processing email 18...
#   Subject: BJP's poll win triggers D-St rally | FIIs' most hated stocks | GQG
#  stands by Adani again
#   From: ET Markets <newsletter@economictimesnews.com>
#   Saved email to data\email_18.txt
# Processing email 19...
#   Subject: =?UTF-8?Q?User,_Research_driven_insig?=
#  =?UTF-8?Q?hts_for_long-term_success_=F0=9F=8E=AF?=
#   From: Angel One <mailer@angelbroking.in>
#   Saved email to data\email_19.txt
# Processing email 20...
#   Subject: TikTok is hiring: Mobile Software Engineer Intern
#   From: Joinrs <info@joinrs.com>
#   Saved email to data\email_20.txt
# Processed 20/5000 emails.
# Processing email 21...
#   Subject: Your ride awaits
#   From: AliExpress <ae-sales.notice06@mail.aliexpress.com>
#   Saved email to data\email_21.txt
# Processing email 22...
#   Subject: =?utf-8?Q?=F0=9F=91=80REDMAGIC=2010=20Pro=3A=20More=20Than=20a=20Display?=
#   From: REDMAGIC Team <news@redmagic.gg>
#   Saved email to data\email_22.txt
# Processing email 23...
#   Subject: =?UTF-8?B?8J+Vte+4j+KAjeKZgu+4jw==?= Can you crack the code to get
#  big savings?
#   From: Jockey <shopjockey@email.jockeycomfort.com>
#   Saved email to data\email_23.txt
# Processing email 24...
#   Subject: =?UTF-8?B?QWN0aW9uIHJlcXVpcmVkIG9uIHlvdXIgSW5hY3RpdmUgUGF5dG0gUGF5bWVudHMgQmFuayBXYWxsZXQ=?=
#   From: =?UTF-8?B?UGF5dG0gUGF5bWVudHMgQmFuaw==?= <no-reply@paytmbank.com>
#   Saved email to data\email_24.txt
# Processing email 25...
#   Subject: Somesh, let's travel together
#   From: "Vrbo" <mail@eg.vrbo.com>
#   Saved email to data\email_25.txt
# Processing email 26...
#   Subject: Missing rapper Janessa Jones has been found: SJPD
#   From: NewsBreak San Jose <newsletter@newsbreakpost.com>
#   Saved email to data\email_26.txt
# Processing email 27...
#   Subject: The dip to buy the dip
#   From: Value Research Stock Advisor <newsletters@valueresearchonline.net>
#   Saved email to data\email_27.txt
# Processing email 28...
#   Subject: =?UTF-8?Q?Indian_House_=F0=9F=8E=B6_fans,_uni?=
#  =?UTF-8?Q?te:_Anyasa_Tour's_here!_=F0=9F=99=8C?=
#   From: BookMyShow <no-reply@mail.bookmyshow.com>
#   Saved email to data\email_28.txt
# Processing email 29...
#   Subject: NTPC Green IPO Day 1 report card | 39 stock ideas | What's weighing
#  on RIL shares?
#   From: ET Markets <newsletter@economictimesnews.com>
#   Saved email to data\email_29.txt
# Processing email 30...
#   Subject: Mastering Feature Selection: Techniques to Boost Your Machine
#  Learning Models | Patwariraghottam in DevOps.dev
#   From: Medium Daily Digest <noreply@medium.com>
#   Saved email to data\email_30.txt
# Processed 30/5000 emails.
# Processing email 31...
#   Subject: Looks for Every Holiday Occasion
#   From: "SKECHERS" <no-reply@emails.skechers.com>
#   Saved email to data\email_31.txt
# Processing email 32...
#   Subject: 'Car Rental ' (USD250.00) added by Gaurav S.
#   From: Splitwise <hello@splitwise.com>
#   Saved email to data\email_32.txt
# Processing email 33...
#   Subject: Somesh, use Chase Auto to find the car that best fits your budget
#   From: Chase  <Chase@e.chase.com>
#   Saved email to data\email_33.txt
# Processing email 34...
#   Subject: Robinhood Legend is ready for you
#   From: Robinhood <noreply@robinhood.com>
#   Saved email to data\email_34.txt
# Processing email 35...
#   Subject: We've received your Chase Freedom Unlimited payment
#   From: Chase <no.reply.alerts@chase.com>
#   Saved email to data\email_35.txt
# Processing email 36...
#   Subject: 2 BHK House Available Near Paithan-Road
#   From: MagicBricks <recos@magicbricks.com>, recos@magicbricks.com
#   Saved email to data\email_36.txt
# Processing email 37...
#   Subject: Your Google Play Order Receipt from 18 Nov 2024
#   From: Google Play <googleplay-noreply@google.com>
#   Saved email to data\email_37.txt
# Processing email 38...
#   Subject: San Jose Police Shoot and Injure Suspect They Say Was Threatening
#  Them With a Knife
#   From: NewsBreak San Jose <newsletter@newsbreakpost.com>
#   Saved email to data\email_38.txt
# Processing email 39...
#   Subject: =?UTF-8?Q?=F0=9F=92=AC_Somesh,_add_Yifu_Fang_and_others?=
#   From: LinkedIn <messages-noreply@linkedin.com>
#   Saved email to data\email_39.txt
# Processing email 40...
#   Subject: =?UTF-8?B?Q29uZ3JhdHMsIFNvbWVzaCBQdXNocGt1bWFyIEJhZ2FkaXlhLiBZ?=
#  =?UTF-8?B?b3XigJl2ZSBiZWVuIGludml0ZWQgdG8gYXBwbHkgZm9yIFBheVBhbCBDcmVk?=
#  =?UTF-8?B?aXTigJlzIHJldXNhYmxlLCBkaWdpdGFsIGNyZWRpdCBsaW5lLg==?=
#   From: "PayPal" <PayPal@emails.paypal.com>
#   Saved email to data\email_40.txt
# Processed 40/5000 emails.
# Processing email 41...
#   Subject: I just requested to connect
#   From: Akash Razdan <invitations@linkedin.com>
#   Saved email to data\email_41.txt
# Processing email 42...
#   Subject: I just requested to connect
#   From: Komal Kumar Vasireddy <invitations@linkedin.com>
#   Saved email to data\email_42.txt
# Processing email 43...
#   Subject: Rigo High Collar Zipper Waffle...
#   From: "Amazon.in" <store-news@amazon.in>
#   Saved email to data\email_43.txt
# Processing email 44...
#   Subject: Train ticket booking made simpler and more economical on YONO SBI!
#   From: YONO SBI <yonosbi@alerts.sbi.co.in>
#   Saved email to data\email_44.txt
# Processing email 45...
#   Subject: Last chance to refinance student debt at a limited-time rate.
#   From: SoFi <no-reply@r.sofi.com>
#   Saved email to data\email_45.txt
# Processing email 46...
#   Subject: Order 1108847814485491: awaiting confirmation
#   From: AliExpress <transaction@notice.aliexpress.com>
#   Saved email to data\email_46.txt
# Processing email 47...
#   Subject: You're Invited: Access Red Hat Summit: Connect On-Demand Content!
#   From: Red Hat India <email@engage.redhat.com>
#   Saved email to data\email_47.txt
# Processing email 48...
#   Subject: surekha has shared their Beed Bypass Residential House with you
#   From: Magicbricks <feed.alrt@magicbricks.com>
#   Saved email to data\email_48.txt
# Processing email 49...
#   Subject: =?utf-8?Q?Apply=20Today:=20SF=20Bay=20Residents:=20=20Paid=20In=20Person=20Focus=20Group=20on=20the=20topic=20of=20Social=20Media=20and=20Advertising=20-=20Earn=20$150.00=20via=20Cash?=
#   From: "User Interviews" <support@userinterviews.com>
#   Saved email to data\email_49.txt
# Processing email 50...
#   Subject: Software Engineer and 39 more "software engineer" opportunities
#   From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
#   Saved email to data\email_50.txt
# Processed 50/5000 emails.
# Processing email 51...
#   Subject: =?UTF-8?Q?=E2=80=9Ccomputer_vision_engineer=E2=80=9D:_Silvr_?=
#  =?UTF-8?Q?-_Computer_Vision_Engineer_and_more?=
#   From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
#   Saved email to data\email_51.txt
# Processing email 52...
#   Subject: REMINDER: HSBC Credit Card OFFER For Nov 2024
#   From: Team BankBazaar <creditcard+ratealert@bankbazaar.com>
#   Saved email to data\email_52.txt
# Processing email 53...
#   Subject: =?UTF-8?Q?=E2=80=9Cdeep_learning_engineer=E2=80=9D:_NVIDIA_-_S?=
#  =?UTF-8?Q?enior_Deep_Learning_Software_Engineer?=
#   From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
#   Saved email to data\email_53.txt
# Processing email 54...
#   Subject: =?UTF-8?B?8J+SuA==?= Facing the toughest talk yet...
#   From: On the Money by SoFi <SoFi@daily.sofi.com>
#   Saved email to data\email_54.txt
# Processing email 55...
#   Subject: =?UTF-8?Q?Watch_Now=E2=80=94NVIDIA=E2=80=99s_SC24_Special_Address?=
#   From: NVIDIA <news@nvidia.com>
#   Saved email to data\email_55.txt
# Processing email 56...
#   Subject: Order 1108839960865491: awaiting confirmation
#   From: AliExpress <transaction@notice.aliexpress.com>
#   Saved email to data\email_56.txt
# Processing email 57...
#   Subject: Order 1108847814485491: awaiting confirmation
#   From: AliExpress <transaction@notice.aliexpress.com>
#   Saved email to data\email_57.txt
# Processing email 58...
#   Subject: Akash just messaged you
#   From: Akash Razdan via LinkedIn <messaging-digest-noreply@linkedin.com>
#   Saved email to data\email_58.txt
# Processing email 59...
#   Subject: =?utf-8?B?Qm9udXMgU3RhcnMgc2hpbmUgbWVycnkgJiBicmlnaHQg8J+Mnw==?=
#   From: "Starbucks Rewards" <rewards@e.starbucks.com>
#   Saved email to data\email_59.txt
# Processing email 60...
#   Subject: =?utf-8?B?QmxhY2sgRnJpZGF5IGlzIGJhY2sgZWFybHksIFNvbWVzaCA=?=
#  =?utf-8?B?8J+YiiBTYXZlIHVwIHRvICQxLDU3NSsgb24gR2FsYXh5IFogRm9sZDYu?=
#   From: "Samsung" <samsung@innovations.samsungusa.com>
#   Saved email to data\email_60.txt
# Processed 60/5000 emails.
# Processing email 61...
#   Subject: Security alert
#   From: Google <no-reply@accounts.google.com>
#   Saved email to data\email_61.txt
# Processing email 62...
#   Subject: Security alert
#   From: Google <no-reply@accounts.google.com>
#   Saved email to data\email_62.txt
# Processing email 63...
#   Subject: Somesh, as a Chase customer, we're pleased to offer up to $700 and easy investing
#   From: "J.P. Morgan Wealth Management" <no-reply@mcw.jpmorgan.com>
#   Saved email to data\email_63.txt
# Processing email 64...
#   Subject: 2 BHK House Available Near Paithan-Road
#   From: MagicBricks <recos@magicbricks.com>, recos@magicbricks.com
#   Saved email to data\email_64.txt
# Processing email 65...
#   Subject: An account has been added to your file
#   From: American Express MyCredit Guide
#  <noreply@mycredit-guide.americanexpress.com>
#   Saved email to data\email_65.txt
# Processing email 66...
#   Subject: Aditi signed in on a new device
#   From: Google  <families-noreply@google.com>
#   Saved email to data\email_66.txt
# Processing email 67...
#   Subject: Aditi signed in on a new device
#   From: Google  <families-noreply@google.com>
#   Saved email to data\email_67.txt
# Processing email 68...
#   Subject: Aditi signed in on a new device
#   From: Google  <families-noreply@google.com>
#   Saved email to data\email_68.txt
# Processing email 69...
#   Subject: Somesh, you only have 48 hours!
#   From: "Fabletics Sale" <fabletics@emails.fabletics.com>
#   Saved email to data\email_69.txt
# Processing email 70...
#   Subject: Here is your eGift Card from The Cheesecake Factory!
#   From: =?utf-8?q?The_Cheesecake_Factory?=
#  <thecheesecakefactorygiftcards@cashstar.com>
#   Saved email to data\email_70.txt
# Processed 70/5000 emails.
# Processing email 71...
#   Subject: =?utf-8?B?SW50cm9kdWNpbmc6IFF1aWNrLWNsaWNrIEFkb2JlIFN0b2NrIA==?=
#  =?utf-8?B?Y3VzdG9taXNhdGlvbnMgd2l0aCBBSQ==?=
#   From: "Adobe Stock" <mail@mail.adobe.com>
#   Saved email to data\email_71.txt
# Processing email 72...
#   Subject: =?utf-8?Q?Reminder:_=F0=9F=93=8C_Hammer_Holidays_?=
#   From: Hammer Theatre Center  <hammertheatre-marketing@sjsu.edu>
#   Saved email to data\email_72.txt
# Processing email 73...
#   Subject: =?UTF-8?Q?Start_your_SIP_in_Hi-Conviction_Flexicap_Portfolio_?=
#  =?UTF-8?Q?=F0=9F=9A=80=F0=9F=93=8A?=
#   From: Motilal Oswal Mutual Fund <noreply@motilaloswal.com>
#   Saved email to data\email_73.txt
# Processing email 74...
#   Subject: Order 1108839960905491: awaiting confirmation
#   From: AliExpress <transaction@notice.aliexpress.com>
#   Saved email to data\email_74.txt
# Processing email 75...
#   Subject: surekha (Owner)  has a Residential House in Beed Bypass for you
#   From: Magicbricks <projectsonmb@magicbricks.com>
#   Saved email to data\email_75.txt
# Processing email 76...
#   Subject: Dalia job feed for Somesh
#   From: Dalia <updates@daliajobs.com>
#   Saved email to data\email_76.txt
# Processing email 77...
#   Subject: Do this one thing for cash back
#   From: "PayPal" <PayPal@emails.paypal.com>
#   Saved email to data\email_77.txt
# Processing email 78...
#   Subject: =?UTF-8?B?TmV3IGZvciB5b3UsIFNvbWVzaCBQdXNocGt1bWFyISBPdXIgdG9w?=
#  =?UTF-8?B?IGNyZWRpdCBjYXJkIHJlY29tbWVuZGF0aW9uc+KApg==?=
#   From: "Experian" <support@e.usa.experian.com>
#   Saved email to data\email_78.txt
# Processing email 79...
#   Subject: =?UTF-8?Q?It=E2=80=99s_Beginning_to_Look_a_Lot_Like_Christmas_Near_You!?=
#   From: "Recreation.gov" <AdventureAwaits@recreation.gov>
#   Saved email to data\email_79.txt
# Processing email 80...
#   Subject: Celebrate National Hiking Day at UC Davis Arboretum Trail today!
#   From: AllTrails <no-reply@email.alltrails.com>
#   Saved email to data\email_80.txt
# Processed 80/5000 emails.
# Processing email 81...
#   Subject: =?utf-8?B?VG9tb3Jyb3c6IExhc3QgRHJpZnQgTmlnaHQgaW4gMjAyNCHCoA==?=
#   From: "K1 Speed" <member@from.k1speed.com>
#   Saved email to data\email_81.txt
# Processing email 82...
#   Subject: SITEWIDE DEALS ENDING SOON
#   From: "Fabletics Sale" <fabletics@emails.fabletics.com>
#   Saved email to data\email_82.txt
# Processing email 83...
#   Subject: Somesh Bagadiya, Rental Residential Houses handpicked for you
#   From: Magicbricks <propmb@magicbricks.com>
#   Saved email to data\email_83.txt
# Processing email 84...
#   Subject: Google Payments: Payment method updated for Somesh Bagadiya
#   From: Google Payments <payments-noreply@google.com>
#   Saved email to data\email_84.txt
# Processing email 85...
#   Subject: Few minutes for your Financial Growth!
#   From: Invesco Mutual Fund <mfmarketing@invesco.com>
#   Saved email to data\email_85.txt
# Processing email 86...
#   Subject: Welcome to your family group
#   From: Google  <families-noreply@google.com>
#   Saved email to data\email_86.txt
# Processing email 87...
#   Subject: =?UTF-8?Q?Tap_here_to_catch_the_Rainbow!_=F0=9F=98=8A=F0=9F=8C=88?=
#   From: MakeMyTrip <noreply@zen-makemytrip.com>
#   Saved email to data\email_87.txt
# Processing email 88...
#   Subject: RBL Bank BookMyShow Play Credit Card E-statement dated 22-11-2024
#   From: Statement of Account <statements@rblbank.com>
#   Saved email to data\email_88.txt
# Processing email 89...
#   Subject: REMINDER: Use your monthly perk!
#   From: "7-Eleven" <7-eleven@mail.7-eleven.com>
#   Saved email to data\email_89.txt
# Processing email 90...
#   Subject: You have turned off your Recurring Investment
#   From: Acorns <accounts@notifications.acorns.com>
#   Saved email to data\email_90.txt
# Processed 90/5000 emails.
# Processing email 91...
#   Subject: To pair with what you purchased
#   From: AliExpress <ae-market.promotion00@mail.aliexpress.com>
#   Saved email to data\email_91.txt
# Processing email 92...
#   Subject: =?UTF-8?B?JDEyLjk5IHdvbWVu4oCZcyBzd2VhdGVycz8hIFRoYXTigJlzIGE=?=
# 	=?UTF-8?B?IGdpZnQgdGhleeKAmWxsIOKdpO+4jw==?=
#   From: =?UTF-8?B?TWFjeSdzIEJsYWNrIEZyaWRheQ==?= <shop@emails.macys.com>
#   Saved email to data\email_92.txt
# Processing email 93...
#   Subject: Gamma update: 10 AI image models now available
#   From: Gamma <hello@gamma.app>
#   Saved email to data\email_93.txt
# Processing email 94...
#   Subject: =?UTF-8?Q?Your_payment_of_=E2=82=B9_206.0_to_SWIGGY_was_successful?=
#   From: Amazon Pay India <no-reply@amazonpay.in>
#   Saved email to data\email_94.txt
# Processing email 95...
#   Subject: =?utf-8?B?IkNhcmVlciBPcHBvcnR1bml0aWVzIGluIHRoZSBVU0EiIGFmdGVy?=
# 	=?utf-8?B?IGFuIE1TIGZyb20gYSB0b3AgMTAwIEdsb2JhbCBVbml2ZXJzaXR5IHwgVHVl?=
# 	=?utf-8?B?IGF0IDggUE0gIPCfk4Y=?=
#   From: "University of Arizona Team at Great Learning" <msba.uoa@course.mygreatlearning.com>
#   Saved email to data\email_95.txt
# Processing email 96...
#   Subject: Take up to 25% off for Black Friday Early Access
#   From: "Philips" <info@amer.ph.mc.philips.com>
#   Saved email to data\email_96.txt
# Processing email 97...
#   Subject: Somesh, don't miss out! Redeem your offers
#   From: "Amex Offers from American Express" <americanexpress@member.americanexpress.com>
#   Saved email to data\email_97.txt
# Processing email 98...
#   Subject: =?UTF-8?B?4q2Q?= Our favorite sleepwear styles are yours
#   From: Jockey <shopjockey@email.jockeycomfort.com>
#   Saved email to data\email_98.txt
# Processing email 99...
#   Subject: Upcoming equity SIPs for Mon, 18 Nov 2024
#   From: "Zerodha" <noreply@alertsmailer.zerodha.net>
#   Saved email to data\email_99.txt
# Processing email 100...
#   Subject:
# 	Download your Premium Receipt |Tata AIA Life Insurance Policy  C229413627
#   From: "TATA AIA Life Insurance" <service@tataaia.com>
#   Saved email to data\email_100.txt
# Processed 100/5000 emails.
# Processing email 101...
#   Subject: Give the Gift of Tickets This Holiday Season
#   From: "Monster Jam" <MonsterJam@email.feld-inc.com>
#   Saved email to data\email_101.txt
# Processing email 102...
#   Subject: Somesh  24 hours to go-Job Market, Team Building & Future of Work
#   - virtual Event
#   From: ASEI Organization <aseiusa@asei.ccsend.com>
#   Saved email to data\email_102.txt
# Processing email 103...
#   Subject: Mike Tyson heartbreak after four-year-old daughter died in horrifying
#  treadmill accident
#   From: NewsBreak For You <newsletter@newsbreakpost.com>
#   Saved email to data\email_103.txt
# Processing email 104...
#   Subject: Explore Claude models to find your perfect match
#   From: Anthropic Team <team@email2.anthropic.com>
#   Saved email to data\email_104.txt
# Processing email 105...
#   Subject: Ditch your high-interest credit card debt.
#   From: SoFi <no-reply@r.sofi.com>
#   Saved email to data\email_105.txt
# Processing email 106...
#   Subject: =?utf-8?B?VGhlIGJpZ2dlc3QgQ3liZXIgRGVhbHMgYXJlIGhlcmXCoA==?=
#   From: "Honey" <insiderdeals@my.joinhoney.com>
#   Saved email to data\email_106.txt
# Processing email 107...
#   Subject: =?utf-8?Q?=F0=9F=93=8C_Hammer_Holidays_?=
#   From: Hammer Theatre Center  <hammertheatre-marketing@sjsu.edu>
#   Saved email to data\email_107.txt
# Processing email 108...
#   Subject: Your Scheduled Payment
#   From: Discover Card <discover@services.discover.com>
#   Saved email to data\email_108.txt
# Processing email 109...
#   Subject: RE: Reservation at Double Queen Bedroom_Western Themed_Bryce Canyon
#  for Nov 29 - 30, 2024
#   From: Airbnb <express@airbnb.com>
#   Saved email to data\email_109.txt
# Processing email 110...
#   Subject: Your Daily Digest for Fri, 11/15 is ready to view
#   From: USPS Informed Delivery <USPSInformeddelivery@email.informeddelivery.usps.com>
#   Saved email to data\email_110.txt
# Processed 110/5000 emails.
# Processing email 111...
#   Subject: Get Fresh Again, Somesh!
#   From: theCut <no-reply@thecut.co>
#   Saved email to data\email_111.txt
# Processing email 112...
#   Subject: Fulfil your business aspirations with a Pre-approved Loan Against Property offer!
#   From: ICICI Bank <services@custcomm.icicibank.com>
#   Saved email to data\email_112.txt
# Processing email 113...
#   Subject: surekha has shared their Beed Bypass Residential House with you
#   From: Magicbricks <propmb@magicbricks.com>
#   Saved email to data\email_113.txt
# Processing email 114...
#   Subject: Weekly Drop: 50000 USDC
#   From: Coinbase <info@mail.coinbase.com>
#   Saved email to data\email_114.txt
# Processing email 115...
#   Subject: Don't forget to use your 30% discount code
#   From: Universal Music Group <info@us.umusic-online.com>
#   Saved email to data\email_115.txt
# Processing email 116...
#   Subject: =?utf-8?B?SW1wb3J0YW50IE5vdGljZTogU2NoZWR1bGVkIE1haW50ZW5h?=
# 	=?utf-8?B?bmNlIG9uIDE3dGggYW5kIDI0dGggTm924oCZMjQgezAwOjMwIEFNIElT?=
# 	=?utf-8?B?VCB0byAzOjAwIEFNIElTVCAoMi41IEhvdXJzKX0=?=
#   From: HDFC Bank <information@hdfcbank.net>
#   Saved email to data\email_116.txt
# Processing email 117...
#   Subject: Software Engineer, Data Mobility and 39 more "software engineer"
#  opportunities
#   From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
#   Saved email to data\email_117.txt
# Processing email 118...
#   Subject: Why can't we just launch all of Earth's garbage into the sun?
#   From: "Best of MSN (Start Unfold)" <msn@email2.microsoft.com>
#   Saved email to data\email_118.txt
# Processing email 119...
#   Subject: Prominent figure from Canada's trucker protests against COVID-19
#  restrictions found guilty
#   From: "Best of MSN (MSN Unfold)" <msn@email2.microsoft.com>
#   Saved email to data\email_119.txt
# Processing email 120...
#   Subject: The rise of the Chief AI Officer: Is your organization ready?
#   From: AI Accelerator Institute via LinkedIn
#  <newsletters-noreply@linkedin.com>
#   Saved email to data\email_120.txt
# Processed 120/5000 emails.
# Processing email 121...
#   Subject: New cash back offers for you.
#   From: "PayPal" <PayPal@emails.paypal.com>
#   Saved email to data\email_121.txt
# Processing email 122...
#   Subject: =?UTF-8?B?8J+SuA==?= What are tariffs anyway?
#   From: On the Money by SoFi <SoFi@daily.sofi.com>
#   Saved email to data\email_122.txt
# Processing email 123...
#   Subject: NEFT Transaction
#   From: neftinfo.itps@alerts.sbi.co.in
#   Saved email to data\email_123.txt
# Processing email 124...
#   Subject: Get Thanksgiving ingredients delivered fast!
#   From: Instacart <no-reply@customers.instacartemail.com>
#   Saved email to data\email_124.txt
# Processing email 125...
#   Subject: Your Acorns Later withdrawal request
#   From: Acorns <info@notifications.acorns.com>
#   Saved email to data\email_125.txt
# Processing email 126...
#   Subject: Google Payments: Payment method updated for Somesh
#   From: Google Payments <payments-noreply@google.com>
#   Saved email to data\email_126.txt
# Processing email 127...
#   Subject: Order 1108847814465491: delivered
#   From: AliExpress <transaction@notice.aliexpress.com>
#   Saved email to data\email_127.txt
# Processing email 128...
#   Subject: Field Boundary Detection in Satellite Imagery Using the SAM2 Model |
#  Mahyar Aboutalebi, Ph.D. =?UTF-8?B?8J+Okw==?= in Towards Data Science
#   From: Medium Daily Digest <noreply@medium.com>
#   Saved email to data\email_128.txt
# Processing email 129...
#   Subject: Somesh - 4 days to go for an interactive session on the Upside of
#  Sustainability. If you haven't already, REGISTER NOW!
#   From: ASEI Organization <vu0809-gmail.com@shared1.ccsend.com>
#   Saved email to data\email_129.txt
# Processing email 130...
#   Subject: Thank you for your interest in the Discover Cisco in 60: A Day in the Life as an Early in Career Cisco Employee event
#   From: Cisco Recruiting <donotreply@cisco.avature.net>
#   Saved email to data\email_130.txt
# Processed 130/5000 emails.
# Processing email 131...
#   Subject: Fashionfibre Jeans
#   From: "Amazon.in" <store-news@amazon.in>
#   Saved email to data\email_131.txt
# Processing email 132...
#   Subject: SBI Credit Card OFFER for Nov 2024
#   From: Team BankBazaar <creditcard+ratealert@bankbazaar.com>
#   Saved email to data\email_132.txt
# Processing email 133...
#   Subject: 2 BHK House Available Near Paithan-Road
#   From: MagicBricks <recos@magicbricks.com>, recos@magicbricks.com
#   Saved email to data\email_133.txt
# Processing email 134...
#   Subject: =?UTF-8?B?8J+kqw==?= The secret is out: up to 75% OFF is yours!
#   From: Jockey <shopjockey@email.jockeycomfort.com>
#   Saved email to data\email_134.txt
# Processing email 135...
#   Subject: =?utf-8?B?TmV3IHRyZWF0bWVudCB0aW1lcyBhcmUgYXZhaWxhYmxlISDwn5iy?=
#   From: "Hand and Stone Massage and Facial Spa" <noreply@email.handandstone.com>
#   Saved email to data\email_135.txt
# Processing email 136...
#   Subject: Bishop T.D. Jakes suffers medical incident following sermon
#   From: NewsBreak For You <newsletter@newsbreakpost.com>
#   Saved email to data\email_136.txt
# Processing email 137...
#   Subject: Ignore it all
#   From: Dhirendra Kumar <newsletters@valueresearchonline.net>
#   Saved email to data\email_137.txt
# Processing email 138...
#   Subject: =?UTF-8?Q?Stay_Informed,_Stay_Ahead!_Sub?=
#  =?UTF-8?Q?scribe_Now_&_Get_Flat_30%_Off=F0=9F=91=88?=
#   From: ET Prime <newsletter@notifications-economictimes.com>
#   Saved email to data\email_138.txt
# Processing email 139...
#   Subject: Update payment method to avoid Gmail interruptions
#   From: Google One <googleone-updates-noreply@google.com>
#   Saved email to data\email_139.txt
# Processing email 140...
#   Subject: Account activity: New payment method added
#   From: Airbnb <automated@airbnb.com>
#   Saved email to data\email_140.txt
# Processed 140/5000 emails.
# Processing email 141...
#   Subject: =?UTF-8?Q?We_Just_Made_Your_Int=E2=80=99l_Travel_Experience_Better!_?=
#  =?UTF-8?Q?=E2=9C=88=EF=B8=8F?=
#   From: MakeMyTrip <noreply@zen-makemytrip.com>
#   Saved email to data\email_141.txt
# Processing email 142...
#   Subject: 3M Ear Plug
#   From: "Amazon.in" <store-news@amazon.in>
#   Saved email to data\email_142.txt
# Processing email 143...
#   Subject: Put your $80 off towards more than just groceries
#   From: Instacart <no-reply@customers.instacartemail.com>
#   Saved email to data\email_143.txt
# Processing email 144...
#   Subject: =?utf-8?q?From_Nano_to_Xavier_NX:_NVIDIA_Jetson_Solutions_for_AI_Innovato?= =?utf-8?q?rs=0D=0A?=
#   From: Thinkrobotics India <updates@thinkrobotics.com>
#   Saved email to data\email_144.txt
# Processing email 145...
#   Subject: Somesh Pushpkumar, it's time to check your utilization!
#   From: "Experian" <support@e.usa.experian.com>
#   Saved email to data\email_145.txt
# Processing email 146...
#   Subject: Settlement of unused funds
#   From: "Zerodha" <noreply-alerts@qmailer.zerodha.net>
#   Saved email to data\email_146.txt
# Processing email 147...
#   Subject: More Grand Canyon Village homes this way =?UTF-8?B?8J+RiQ==?=
#   From: Airbnb <discover@airbnb.com>
#   Saved email to data\email_147.txt
# Processing email 148...
#   Subject: Save Up to =?UTF-8?B?4oK5NTAw?= on Your Credit Card Bills!
#   From: IndusInd Bank <support.indie@indusind.com>
#   Saved email to data\email_148.txt
# Processing email 149...
#   Subject: Tick mark your bucket list with a Personal Loan on ICICI Bank Credit Card
#   From: "ICICI Bank" <services@custcomm.icicibank.com>
#   Saved email to data\email_149.txt
# Processing email 150...
#   Subject: Sr. Deep Learning Engineer - Autonomous Vehicle Startup - "deep
#  learning engineer" opportunity
#   From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
#   Saved email to data\email_150.txt
# Processed 150/5000 emails.
# Processing email 151...
#   Subject: A shift is up for grabs
#   From: 7shifts Scheduling <notifications@7shifts.com>
#   Saved email to data\email_151.txt
# Processing email 152...
#   Subject: Ships from the US
#   From: AliExpress <ae-sales.promotion01@mail.aliexpress.com>
#   Saved email to data\email_152.txt
# Processing email 153...
#   Subject: Black & Mild Lyrics Now Available
#   From: "7-Eleven" <7-eleven@mail.7-eleven.com>
#   Saved email to data\email_153.txt
# Processing email 154...
#   Subject: =?UTF-8?B?RnVuZHMgLyBTZWN1cml0aWVzIEJhbGFuY2U=?=
#   From: =?UTF-8?B?QlNFIEFMRVJUUw==?= <info@bseindia.in>
#   Saved email to data\email_154.txt
# Processing email 155...
#   Subject: Gaurav Surtani mentioned you in a comment
#   From: LinkedIn <messages-noreply@linkedin.com>
#   Saved email to data\email_155.txt
# Processing email 156...
#   Subject: =?utf-8?Q?December_Applause___=F0=9F=91=8F__?=
#   From: Hammer Theatre Center <hammertheatre@sjsu.edu>
#   Saved email to data\email_156.txt
# Processing email 157...
#   Subject: =?UTF-8?B?SW1wb3J0YW50IE5vdGljZTogWW91IGhhdmUgZnJlZSBEaXNjb3Y=?=
# 	=?UTF-8?B?ZXLCriBzZWN1cml0eSBiZW5lZml0cyB0byBhY3RpdmF0ZQ==?=
#   From: =?UTF-8?B?RGlzY292ZXIgQ2FyZA==?= <discover@card-e.em.discover.com>
#   Saved email to data\email_157.txt
# Processing email 158...
#   Subject: Exclusive Invite: Graduate STEM Programs in the U.S. [Virtual
#  Event]
#   From: GRE Program at ETS <gre-program@mailing.ets.org>
#   Saved email to data\email_158.txt
# Processing email 159...
#   Subject: =?UTF-8?B?eW91ciBJQ0lDSSBBbWF6b24gUGF5IGNyZWRpdCBjYXJkIHBlcmtzIGFyZSBjaGFuZ2luZy4=?=
#   From: =?UTF-8?B?Q1JFRA==?= <from@cred.club>
#   Saved email to data\email_159.txt
# Processing email 160...
#   Subject: =?utf-8?B?TmV3IHRyZWF0bWVudCB0aW1lcyBhcmUgYXZhaWxhYmxlISDwn5iy?=
#   From: "Hand and Stone Massage and Facial Spa" <noreply@email.handandstone.com>
#   Saved email to data\email_160.txt
# Processed 160/5000 emails.
# Processing email 161...
#   Subject: New job(s) match your search on Google Careers
#   From: careers-noreply@google.com
#   Saved email to data\email_161.txt
# Processing email 162...
#   Subject: New jobs posted from Gallo
#   From: ejgallo-jobnotification@noreply.jobs2web.com
#   Saved email to data\email_162.txt
# Processing email 163...
#   Subject: I want to connect
#   From: Braden Hamm <invitations@linkedin.com>
#   Saved email to data\email_163.txt
# Processing email 164...
#   Subject: I want to connect
#   From: Saurabh Suchak <invitations@linkedin.com>
#   Saved email to data\email_164.txt
# Processing email 165...
#   Subject: Keep up with Alexa
#   From: "Amazon.in" <store-news@amazon.in>
#   Saved email to data\email_165.txt
# Processing email 166...
#   Subject: New Nokia career opportunities at Nokia Global Career Site
#   From: NokiaME DoNotReply <donotreply.nokiaME@people.nokia.com>
#   Saved email to data\email_166.txt
# Processing email 167...
#   Subject: Here are some new roles at Waymo
#   From: The Talent Acquisition team at Waymo <user-e65a8e09c91dc79cdac854bf73c74dd1@waymo.mail.clinchtalent.com>
#   Saved email to data\email_167.txt
# Processing email 168...
#   Subject: Unlock Your Exclusive Offer: 20% Off Xpress Biz + Extra 5% for Members!
#   From: Air India Express <noreply@promo.airindiaexpress.com>
#   Saved email to data\email_168.txt
# Processing email 169...
#   Subject: Disney Debit: Winter Cardmember offers are here!
#   From: "Disney Debit" <disneydebit@em.disneydebit.com>
#   Saved email to data\email_169.txt
# Processing email 170...
#   Subject: A free gift from ParkMobile =?UTF-8?B?8J+amQ==?=
#   From: ParkMobile <hello@mail.parkmobile.io>
#   Saved email to data\email_170.txt
# Processed 170/5000 emails.
# Processing email 171...
#   Subject: =?utf-8?q?Day_8_is_LIVE=3A_No_Fees_on_Select_Crypto_Pairs_Today!=F0=9F=92=B0?=
#   From: Team ZebPay <no-reply@email.zebpay.com>
#   Saved email to data\email_171.txt
# Processing email 172...
#   Subject: 12 arrested in grand theft operation at Target in San Jose: sheriff
#   From: NewsBreak San Jose <newsletter@newsbreakpost.com>
#   Saved email to data\email_172.txt
# Processing email 173...
#   Subject: =?UTF-8?Q?"I_GOT_FINED_=C2=A3850_FOR_USING_ELECTRIC_SCOOTER"?=
#   From: Reddit <noreply@redditmail.com>
#   Saved email to data\email_173.txt
# Processing email 174...
#   Subject: =?utf-8?B?SGVsbG8gQ3liZXIgTW9udGghIPCfkrvCoA==?=
#   From: "Honey" <insiderdeals@my.joinhoney.com>
#   Saved email to data\email_174.txt
# Processing email 175...
#   Subject: Your Friday evening trip with Uber
#   From: Uber Receipts <noreply@uber.com>
#   Saved email to data\email_175.txt
# Processing email 176...
#   Subject: Your Friday evening trip with Uber
#   From: Uber Receipts <noreply@uber.com>
#   Saved email to data\email_176.txt
# Processing email 177...
#   Subject: SHAP Values vs Feature Importance | Amit Yadav in Biased-Algorithms
#   From: Medium Daily Digest <noreply@medium.com>
#   Saved email to data\email_177.txt
# Processing email 178...
#   Subject: Avail balance fund in your HDFC Credila Loan Account A2304200070
#   From: Credila <no-reply@mailer.credila.com>
#   Saved email to data\email_178.txt
# Processing email 179...
#   Subject: Transaction alert for your ICICI Bank Credit Card
#   From: credit_cards@icicibank.com
#   Saved email to data\email_179.txt
# Processing email 180...
#   Subject: =?UTF-8?B?SXMgeW91ciBwb3J0Zm9saW8gc2V0IHRvIGdyb3c/IPCfk4jwn4yx?=
#   From: =?UTF-8?B?UGhvbmVQZQ==?= <noreply@phonepe.com>
#   Saved email to data\email_180.txt
# Processed 180/5000 emails.
# Processing email 181...
#   Subject: Keep up with Alexa
#   From: "Amazon.in" <store-news@amazon.in>
#   Saved email to data\email_181.txt
# Processing email 182...
#   Subject: Welcome to Free Spirit!
#   From: =?UTF-8?B?RnJlZSBTcGlyaXQ=?= <FreeSpirit@fly.spirit-airlines.com>
#   Saved email to data\email_182.txt
# Processing email 183...
#   Subject: Psst...get =?UTF-8?B?JDgw4oCUZ29vZA==?= for delivery or pickup
#   From: Instacart <no-reply@customers.instacartemail.com>
#   Saved email to data\email_183.txt
# Processing email 184...
#   Subject: ET ePaper | Read your daily newspaper in pdf format now
#   From: The Economic Times <newsletter@economictimesnews.com>
#   Saved email to data\email_184.txt
# Processing email 185...
#   Subject: =?UTF-8?B?8J+OiUZE?= rates just skyrocketed to
#  =?UTF-8?B?Ny45OSUh8J+agA==?=
#   From: IndusInd Bank <indusind_bank@indusind.com>
#   Saved email to data\email_185.txt
# Processing email 186...
#   Subject: A shift is up for grabs
#   From: 7shifts Scheduling <notifications@7shifts.com>
#   Saved email to data\email_186.txt
# Processing email 187...
#   Subject: =?UTF-8?Q?=E2=80=9Ccomputer_vision_engineer=E2=80=9D:_The_New_York_Consu?=
#  =?UTF-8?Q?lting_Group_-_Computer_Vision_Engineer_and_more?=
#   From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
#   Saved email to data\email_187.txt
# Processing email 188...
#   Subject: We gotta tell you something =?UTF-8?B?8J+kqw==?=
#   From: Zomato <noreply@mailers.zomato.com>
#   Saved email to data\email_188.txt
# Processing email 189...
#   Subject: Akash just messaged you
#   From: Akash Razdan via LinkedIn <messaging-digest-noreply@linkedin.com>
#   Saved email to data\email_189.txt
# Processing email 190...
#   Subject: =?UTF-8?Q?=E2=80=9Cdeep_learning_engineer=E2=80=9D:_Bot_Auto_-_Deep_Lear?=
#  =?UTF-8?Q?ning_Engineer/Researcher_-_All_levels_and_more?=
#   From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
#   Saved email to data\email_190.txt
# Processed 190/5000 emails.
# Processing email 191...
#   Subject: =?UTF-8?Q?=E2=80=9Csoftware_engineer=E2=80=9D:_Journalyt?=
#  =?UTF-8?Q?ic_-_Software_Engineer_and_more?=
#   From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
#   Saved email to data\email_191.txt
# Processing email 192...
#   Subject: Your rewards balance has reached 50 POINTS
#   From: Chase <no.reply.alerts@chase.com>
#   Saved email to data\email_192.txt
# Processing email 193...
#   Subject: Defy gravity on Peacock at no extra cost
#   From: Instacart <no-reply@customers.instacartemail.com>
#   Saved email to data\email_193.txt
# Processing email 194...
#   Subject: Dalia job feed for Somesh
#   From: Dalia <updates@daliajobs.com>
#   Saved email to data\email_194.txt
# Processing email 195...
#   Subject: Your rewards balance has reached 50 POINTS
#   From: Chase <no.reply.alerts@chase.com>
#   Saved email to data\email_195.txt
# Processing email 196...
#   Subject: =?UTF-8?B?8J+SuA==?= Your future self called.
#   From: On the Money by SoFi <SoFi@daily.sofi.com>
#   Saved email to data\email_196.txt
# Processing email 197...
#   Subject: =?UTF-8?B?8J+RiUxpZmUgaW5zdXJhbmNlIDEwMTogSXTigJlz?= in here.
#   From: SoFi <no-reply@r.sofi.com>
#   Saved email to data\email_197.txt
# Processing email 198...
#   Subject: New music from TOMORROW X TOGETHER, Gracie Abrams, Ella Mai, Shawn
#  Mendes, & more
#   From: Universal Music Group <info@us.umusic-online.com>
#   Saved email to data\email_198.txt
# Processing email 199...
#   Subject: Congrats on your new card, Somesh Pushpkumar! Do this next...
#   From: "Experian" <support@e.usa.experian.com>
#   Saved email to data\email_199.txt
# Processing email 200...
#   Subject: Review the new account on your credit report
#   From: Chase Credit Journey <no.reply.alerts@chase.com>
#   Saved email to data\email_200.txt
# Processed 200/5000 emails.
# Processing email 201...
#   Subject: vaishali (Owner)  has a Residential House in Beed Bypass Road for
#  you
#   From: Magicbricks <projectsonmb@magicbricks.com>
#   Saved email to data\email_201.txt
# Processing email 202...
#   Subject: Somesh Pushpkumar, good news: We have the perfect 0% intro APR card for you!
#   From: "Experian" <support@e.usa.experian.com>
#   Saved email to data\email_202.txt
# Processing email 203...
#   Subject: =?utf-8?B?SG93IHRvIChiYXNpY2FsbHkpIGRvd25sb2FkIGEgYnVyZ2VywqA=?=
# 	=?utf-8?B?wqA=?=
#   From: "Shake Shack" <hello@e.shakeshack.com>
#   Saved email to data\email_203.txt
# Processing email 204...
#   Subject: Somesh, Send your friends your half of the brunch bill with American Express
#   From: "American Express" <americanexpress@member.americanexpress.com>
#   Saved email to data\email_204.txt
# Processing email 205...
#   Subject: =?UTF-8?Q?=F0=9F=93=8A_Register_now_for_the_NFO_Webinar_on_21_Nov,_2024_@?=
#  =?UTF-8?Q?_4_pm?=
#   From: Mirae Asset MF <noreply@miraeassetmf.co.in>
#   Saved email to data\email_205.txt
# Processing email 206...
#   Subject: Take a peek in the app to see new restaurants
#   From: Uber Eats <uber@uber.com>
#   Saved email to data\email_206.txt
# Processing email 207...
#   Subject: Cash withdrawals and fund transfers made quicker and safer
#   From: YONO SBI <YONOSBI@communications.sbi.co.in>
#   Saved email to data\email_207.txt
# Processing email 208...
#   Subject: Steam Guard Mobile Authenticator recovery started
#   From: Steam <noreply@steampowered.com>
#   Saved email to data\email_208.txt
# Processing email 209...
#   Subject: Langchain vs Huggingface | Amit Yadav
#   From: Medium Daily Digest <noreply@medium.com>
#   Saved email to data\email_209.txt
# Processing email 210...
#   Subject: Policy on Handling of Good Till Triggered Facility Orders
#   From: NJ Wealth <info@njwealth.co.in>
#   Saved email to data\email_210.txt
# Processed 210/5000 emails.
# Processing email 211...
#   Subject: =?utf-8?B?QUxFUlQ6IEVhcmx5IEFjY2VzcyBFbmRzIFRvbmlnaHQg4pqg77iP?=
# 	=?utf-8?B?4oCL?=
#   From: "Fabletics Sale" <fabletics@emails.fabletics.com>
#   Saved email to data\email_211.txt
# Processing email 212...
#   Subject: =?UTF-8?Q?=E2=80=9Csoftware_engineer=E2=80=9D:_IAN_-_AI_Engineer_and_more?=
#   From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
#   Saved email to data\email_212.txt
# Processing email 213...
#   Subject: Order 1108839960885491: awaiting confirmation
#   From: AliExpress <transaction@notice.aliexpress.com>
#   Saved email to data\email_213.txt
# Processing email 214...
#   Subject: Order 1108839960885491: out for delivery
#   From: AliExpress <transaction@notice.aliexpress.com>
#   Saved email to data\email_214.txt
# Processing email 215...
#   Subject: Our comfiest men's underwear - in festive prints!
#   From: Jockey <shopjockey@email.jockeycomfort.com>
#   Saved email to data\email_215.txt
# Processing email 216...
#   Subject: =?UTF-8?B?SnVzdCBmb3IgeW91OiDigJxWZXR0YWl5YW7igJ0=?=
#   From: Prime Video <no-reply@primevideo.com>
#   Saved email to data\email_216.txt
# Processing email 217...
#   Subject: Somesh, your cash back card benefits are waiting for you
#   From: =?UTF-8?Q?Chase_Freedom_Unlimited=C2=AE?=
#  <no_reply@mcmap.chase.com>
#   Saved email to data\email_217.txt
# Processing email 218...
#   Subject: Nifty can hit 24,500 this week | Adani bonds hit 1-yr low | When to
#  buy new-age stocks
#   From: ET Markets Morning <newsletter@economictimesnews.com>
#   Saved email to data\email_218.txt
# Processing email 219...
#   Subject: [Coming soon] An all-new ET Money App
#   From: ET Money <hello@etmoney.com>
#   Saved email to data\email_219.txt
# Processing email 220...
#   Subject: Acorns Account Email Authentication
#   From: noreply@noreply.acorns.com
#   Saved email to data\email_220.txt
# Processed 220/5000 emails.
# Processing email 221...
#   Subject: New Nokia career opportunities at Nokia Global Career Site
#   From: NokiaME DoNotReply <donotreply.nokiaME@people.nokia.com>
#   Saved email to data\email_221.txt
# Processing email 222...
#   Subject: =?utf-8?q?Introducing_Windsurf:_Tomorrow=E2=80=99s_editor,_today_?= =?utf-8?q?=F0=9F=8C=8A=0A?=
#   From: Kevin from Codeium <kevin.hou@codeium.com>
#   Saved email to data\email_222.txt
# Processing email 223...
#   Subject: =?UTF-8?Q?=E2=80=9Csoftware_engineer=E2=80=9D:_PayPal_-_Software_En?=
#  =?UTF-8?Q?gineer_-_AI/ML_-_Recent_Graduate_and_more?=
#   From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
#   Saved email to data\email_223.txt
# Processing email 224...
#   Subject: mukesh.gutkawala, catch up on moments that you've missed
#   From: "mohit_dudhal on Instagram" <no-reply@mail.instagram.com>
#   Saved email to data\email_224.txt
# Processing email 225...
#   Subject: Your IndusInd credit card rewards can be =?UTF-8?B?Mljwn5KO?=
#   From: IndusInd Bank <support.indie@indusind.com>
#   Saved email to data\email_225.txt
# Processing email 226...
#   Subject: "Help please!!!"
#   From: Reddit <noreply@redditmail.com>
#   Saved email to data\email_226.txt
# Processing email 227...
#   Subject: Purchase your own office space by availing a Pre-approved Commercial Property Loan
#   From: ICICI Bank <services@custcomm.icicibank.com>
#   Saved email to data\email_227.txt
# Processing email 228...
#   Subject: =?UTF-8?Q?Somesh_Pushpkumar,_get_the_FICO=C2=AE_Score_you_want?=
#   From: "Experian" <support@e.usa.experian.com>
#   Saved email to data\email_228.txt
# Processing email 229...
#   Subject: Order 1108839960905491: out for delivery
#   From: AliExpress <transaction@notice.aliexpress.com>
#   Saved email to data\email_229.txt
# Processing email 230...
#   Subject: =?UTF-8?B?8J+SuA==?= Come back and claim a $500 bonus* for your
#  student loan refi.
#   From: SoFi <SoFi@m.sofi.org>
#   Saved email to data\email_230.txt
# Processed 230/5000 emails.
# Processing email 231...
#   Subject: Engineering Virtual Information Session
#   From: UMass Dartmouth Graduate Admissions <graduate@admissions.umassd.edu>
#   Saved email to data\email_231.txt
# Processing email 232...
#   Subject: =?utf-8?q?Important_Update=3A_New_Terms_=26_Policy_for_Futures_Trading_=F0=9F=9A=80?=
#   From: =?utf-8?q?Team_ZebPay_=F0=9F=A6=93?= <no-reply@email.zebpay.com>
#   Saved email to data\email_232.txt
# Processing email 233...
#   Subject: Save 20% sitewide and gear up for the year =?UTF-8?B?8J+Msg==?=
#   From: AllTrails Gear Shop <no-reply@email.alltrails.com>
#   Saved email to data\email_233.txt
# Processing email 234...
#   Subject: you might not like it
#   From: Zomato <noreply@mailers.zomato.com>
#   Saved email to data\email_234.txt
# Processing email 235...
#   Subject: =?UTF-8?Q?=E2=80=9Ccomputer_vision_engineer=E2=80=9D:_Niantic,_Inc_-?=
#  =?UTF-8?Q?_Computer_Vision_Software_Engineer_and_more?=
#   From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
#   Saved email to data\email_235.txt
# Processing email 236...
#   Subject: [GitHub] A third-party OAuth application has been added to your
#  account
#   From: GitHub <noreply@github.com>
#   Saved email to data\email_236.txt
# Processing email 237...
#   Subject: Bring back the Green Sauce Burrito? Done.
#   From: Taco Bell Rewards <bellbuzz@email.tacobell.com>
#   Saved email to data\email_237.txt
# Processing email 238...
#   Subject: =?UTF-8?B?8J+ajSBPbiB0aGUgd2F5OiBPdXIgZmVzdGl2ZSBvZmZlciBmb3IgR3VycHVyYWIgbG9uZyB3ZWVrZW5kIQpCb29rIGJ1c2VzICYgZ2V0IFJzLiAzMDAgb2ZmLiDwn6Wz?=
#   From: =?UTF-8?B?UGF5dG0gT2ZmZXJz?= <noreply@paytmoffers.in>
#   Saved email to data\email_238.txt
# Processing email 239...
#   Subject: =?UTF-8?B?SW1wb3J0cyBhdCBhbGwtdGltZSBoaWdoLCBSZWxpYW5jZS1EaXNuZXkgbWVyZ2VyLCAmIG1vcmUgLSBHcm93dyBEaWdlc3Q=?=
#   From: =?UTF-8?B?R3Jvd3cgRGlnZXN0?= <noreply@dailydigest.groww.in>
#   Saved email to data\email_239.txt
# Processing email 240...
#   Subject: =?UTF-8?B?4p6h77iP?= Load up on these great deals!	40% OFF holiday
#  sleep & lounge, 30% OFF + FREE shipping & more
#   From: Jockey <shopjockey@email.jockeycomfort.com>
#   Saved email to data\email_240.txt
# Processed 240/5000 emails.
# Processing email 241...
#   Subject: =?UTF-8?Q?Prevention_first,_protection_always=F0=9F=9B=A1=EF=B8=8F?=
#   From: PhonePe <noreply@phonepe.com>
#   Saved email to data\email_241.txt
# Processing email 242...
#   Subject: Order 1108836339885491: out for delivery
#   From: AliExpress <transaction@notice.aliexpress.com>
#   Saved email to data\email_242.txt
# Processing email 243...
#   Subject: Re: Invitation from an unknown sender: First Interview - Somesh
#  Bagadiya - Senior AI Engineer/QA... @ Fri 15 Nov 2024 10am - 10:30am (GMT-8) (someshbgd3@gmail.com)
#   From: "William Hinsche, CEO" <william.hinsche@flowai.tech>
#   Saved email to data\email_243.txt
# Processing email 244...
#   Subject: Re: Invitation from an unknown sender: First Interview - Somesh
#  Bagadiya - Senior AI Engineer/QA... @ Fri 15 Nov 2024 10am - 10:30am (GMT-8) (someshbgd3@gmail.com)
#   From: Somesh <someshbgd3@gmail.com>
#   Saved email to data\email_244.txt
# Processing email 245...
#   Subject: Invitation from an unknown sender: First Interview - Somesh Bagadiya
#  - Senior AI Engineer/QA... @ Fri 15 Nov 2024 10am - 10:30am (GMT-8) (someshbgd3@gmail.com)
#   From: "William Hinsche, CEO" <william.hinsche@flowai.tech>
#   Saved email to data\email_245.txt
# Processing email 246...
#   Subject: 2025 Best K-8 Schools Rankings are here!
#   From: "U.S. News Education" <updates@send-edu.usnews.com>
#   Saved email to data\email_246.txt
# Processing email 247...
#   Subject: =?UTF-8?B?8J+UpQ==?= Thermals that will keep you warm & toasty
#   From: Jockey <shopjockey@email.jockeycomfort.com>
#   Saved email to data\email_247.txt
# Processing email 248...
#   Subject: How To Wake Up at 5 A.M. Every Day | Bryan Ye in Better Humans
#   From: Medium Daily Digest <noreply@medium.com>
#   Saved email to data\email_248.txt
# Processing email 249...
#   Subject: =?UTF-8?B?V2hv4oCZcyB0aGUgdG9wIGJyYW5kIG9uIHRoZSBJbnRlcm5ldD8=?=
#   From: "The Webby Awards" <news@email.webbyawards.com>
#   Saved email to data\email_249.txt
# Processing email 250...
#   Subject: =?UTF-8?Q?This_Children=E2=80=99s_Day,_Learn_The_Most_Essential_Full_Form?=
#  =?UTF-8?Q?_for_Your_Child's_Future=F0=9F=93=9A=F0=9F=8E=93?=
#   From: Motilal Oswal Mutual Fund <noreply@motilaloswal.com>
#   Saved email to data\email_250.txt
# Processed 250/5000 emails.
# Processing email 251...
#   Subject: Somesh Pushpkumar, increase your $3,000 credit limit for seasonal shopping
#   From: "Experian" <support@e.usa.experian.com>
#   Saved email to data\email_251.txt
# Processing email 252...
#   Subject: Order 1108847814485491: in your country/region
#   From: AliExpress <transaction@notice.aliexpress.com>
#   Saved email to data\email_252.txt
# Processing email 253...
#   Subject: Earn 100,000 Miles with Halalbooking.com!
#   From: Miles&Smiles <milesandsmiles@milesandsmiles.turkishairlines.com>
#   Saved email to data\email_253.txt
# Processing email 254...
# ...
#  <virtual@services.dmvonline.ca.gov>
#   Saved email to data\email_4918.txt
# Processing email 4919...
#   Subject: Kendall Jenner contrasts her new platinum hair with a chocolate brown
#  dress
#   From: NewsBreak National Headlines <newsletter@newsbreakpost.com>
#   Saved email to data\email_4919.txt
# Processing email 4920...
#   Subject: ET Today's Paper | Your daily newspaper is now ready to read
#   From: The Economic Times <newsletter@economictimesnews.com>
#   Saved email to data\email_4920.txt
# Processed 4920/5000 emails.
# Processing email 4921...
#   Subject: New Nokia career opportunities at Nokia Global Career Site
#   From: NokiaME DoNotReply <donotreply.nokiaME@people.nokia.com>
#   Saved email to data\email_4921.txt
# Processing email 4922...
#   Subject: Somesh, get the big picture. Save up to $3,000 on supersized TVs, soundbars and more.
#   From: "Samsung" <samsung@innovations.samsungusa.com>
#   Saved email to data\email_4922.txt
# Processing email 4923...
#   Subject: =?UTF-8?q?India=E2=80=99s_Silicon_Valley_dream_is_closer_than_you_think?=
#  =?UTF-8?q?=E2=80=94don=E2=80=99t_miss_this_visionary_at_TechSparks!?=
#   From: Team YourStory <info@yourstory.com>
#   Saved email to data\email_4923.txt
# Processing email 4924...
#   Subject: We found something you might like
#   From: "Amazon.com" <store-news@amazon.com>
#   Saved email to data\email_4924.txt
# Processing email 4925...
#   Subject: Alignerr Application Submitted
#   From: Alignerr <noreply@alignerr.com>
#   Saved email to data\email_4925.txt
# Processing email 4926...
#   Subject: Alignerr Application Submitted
#   From: Alignerr <noreply@alignerr.com>
#   Saved email to data\email_4926.txt
# Processing email 4927...
#   Subject: =?utf-8?B?8J+liE91ciBDaGFtcGlvbidzIHdpbm5pbmcgc3RyZWFrIGNvbg==?=
#  =?utf-8?B?dGludWVz4pyo?=
#   From: "Tata AIA Life Insurance" <customer@info.tataaia.com>
#   Saved email to data\email_4927.txt
# Processing email 4928...
#   Subject: The schedule has been posted!
#   From: 7shifts Scheduling <notifications@7shifts.com>
#   Saved email to data\email_4928.txt
# Processing email 4929...
#   Subject: The schedule has been posted!
#   From: 7shifts Scheduling <notifications@7shifts.com>
#   Saved email to data\email_4929.txt
# Processing email 4930...
#   Subject: Your One-time Password for Registration on GOOGLE PAY
#   From: RBL Bank <RBLAlerts@rblbank.com>
#   Saved email to data\email_4930.txt
# Processed 4930/5000 emails.
# Processing email 4931...
#   Subject: A shift is up for grabs
#   From: 7shifts Scheduling <notifications@7shifts.com>
#   Saved email to data\email_4931.txt
# Processing email 4932...
#   Subject: Dravid, KJo dig into Swiggy's IPO pie | Case for holding cash in
#  bull mkt | All about multi-asset funds
#   From: ET Markets Morning <newsletter@economictimesnews.com>
#   Saved email to data\email_4932.txt
# Processing email 4933...
#   Subject: New announcement
#   From: 7shifts Scheduling <notifications@7shifts.com>
#   Saved email to data\email_4933.txt
# Processing email 4934...
#   Subject: =?utf-8?B?RG9u4oCZdCBsZXQgZnJpZW5kcyBtaXNzIG91dCBvbiAkMzAgYm9u?=
# 	=?utf-8?B?dXNlcw==?=
#   From: "Rakuten" <emails@emails.rakuten.com>
#   Saved email to data\email_4934.txt
# Processing email 4935...
#   Subject: =?UTF-8?Q?USPS=C2=AE_Expected_Delivery_on_Monday,_September_23?=
#  =?UTF-8?Q?,_2024_arriving_by_8:00pm_9434636110220960082745?=
#   From: auto-reply@usps.com
#   Saved email to data\email_4935.txt
# Processing email 4936...
#   Subject: Pay down credit card debt and save big with a low fixed-rate personal
#  loan.
#   From: SoFi <no-reply@r.sofi.com>
#   Saved email to data\email_4936.txt
# Processing email 4937...
#   Subject: View: Account update for your HDFC Bank A/c
#   From: HDFC Bank InstaAlerts <alerts@hdfcbank.net>
#   Saved email to data\email_4937.txt
# Processing email 4938...
#   Subject: =?UTF-8?B?4pid77iPICBTb21lc2ggUHVzaHBrdW1hciwgaGVyZeKAmXM=?= how you
#  budget for buying a home.
#   From: SoFi <no-reply@r.sofi.com>
#   Saved email to data\email_4938.txt
# Processing email 4939...
#   Subject: Amazon Great Indian Festival is live for Prime members! Shop now
#   From: Prime Video <no-reply@primevideo.com>
#   Saved email to data\email_4939.txt
# Processing email 4940...
#   Subject: Khush just messaged you
#   From: Khush Patel via LinkedIn <messaging-digest-noreply@linkedin.com>
#   Saved email to data\email_4940.txt
# Processed 4940/5000 emails.
# Processing email 4941...
#   Subject: This Diwali make Authentic and Ageless Investments - Edelweiss Gold
#  and Silver ETF Fund of Fund
#   From: "Edelweiss Mutual Fund" <communications@edelweissmf.com>
#   Saved email to data\email_4941.txt
# Processing email 4942...
#   Subject: Webinar Invite: Aim to Accelerate your growth with HDFC Transportation and Logistics Fund
#   From: HDFC MF <noresponse@hdfcfund.com>
#   Saved email to data\email_4942.txt
# Processing email 4943...
#   Subject: =?utf-8?Q?2024=20Fall=20Chinook=20Salmon=20Are=20Here=21?=
#   From: South Bay Clean Creeks Coalition <c.szymkiewicz@sbcleancreeks.com>
#   Saved email to data\email_4943.txt
# Processing email 4944...
#   Subject: taufa_theory, sunitabagadiya and sweet_tooth2503 have posts
#   From: "taufa_theory on Instagram" <no-reply@mail.instagram.com>
#   Saved email to data\email_4944.txt
# Processing email 4945...
#   Subject: DELIVERED TO YOUR INBOX: Your OCT 2024 Credit Card OFFER
#   From: Team BankBazaar <creditcard+ratealert@bankbazaar.com>
#   Saved email to data\email_4945.txt
# Processing email 4946...
#   Subject: New music from Lady Gaga, The Weeknd, SOPHIE, The Cure, & more
#   From: Universal Music Group <info@us.umusic-online.com>
#   Saved email to data\email_4946.txt
# Processing email 4947...
#   Subject: =?utf-8?B?MTIgY29sb3VyZnVsIGJlYWNoZXMgZm9yIHlvdXIgYnVja2V0IGxp?=
# 	=?utf-8?B?c3Qg8J+Plu+4jw==?=
#   From: "Tripadvisor" <inspiration@mp1.tripadvisor.com>
#   Saved email to data\email_4947.txt
# Processing email 4948...
#   Subject: Your recent job application for Software Engineering for Robotics
#  Co-Op - 11711
#   From: NokiaME DoNotReply <donotreply.nokiaME@people.nokia.com>
#   Saved email to data\email_4948.txt
# Processing email 4949...
#   Subject: Unlock Your Graph Superpowers! Register for free Road to NODES Workshops
#   From: TechGig on behalf of Neo4j <promotion@techgig.com>
#   Saved email to data\email_4949.txt
# Processing email 4950...
#   Subject: Save Big on Festive Shopping at Amazon!
#   From: Offers (SBICard) <Offers@sbicard.com>
#   Saved email to data\email_4950.txt
# Processed 4950/5000 emails.
# Processing email 4951...
#   Subject: Welcome to DashPass, Somesh
#   From: DoorDash <no-reply@doordash.com>
#   Saved email to data\email_4951.txt
# Processing email 4952...
#   Subject: Notice - In Nobroker app,Auto approval is default set for
#  Zomato,Swiggy and Blinkit. steps on How to disable it.
#   From: Megapolis Sunway Society <noreply@nobrokerhood.com>
#   Saved email to data\email_4952.txt
# Processing email 4953...
#   Subject: Rate cuts provide the macro boost
#   From: CoinSwitch <no-reply@coinswitch.co>
#   Saved email to data\email_4953.txt
# Processing email 4954...
#   Subject: Avoid =?UTF-8?B?4oCYQXJleXksIFllIEJoaSBCaW1hYXIh4oCZ?= Moments
#   From: PharmEasy <PEducate@emailer.pharmeasy.in>
#   Saved email to data\email_4954.txt
# Processing email 4955...
#   Subject: Information regarding DirectPay Enrollment
#   From: Discover Card <discover@services.discover.com>
#   Saved email to data\email_4955.txt
# Processing email 4956...
#   Subject: Finding term life insurance this fall =?UTF-8?B?ZG9lc27igJl0?= have
#  to be complicated.
#   From: SoFi <no-reply@r.sofi.com>
#   Saved email to data\email_4956.txt
# Processing email 4957...
#   Subject: =?utf-8?Q?=F0=9F=94=A5The=20REDMAGIC=20Nova=20Gaming=20Tablet=20Early=20Bird=20Offer=20is=20Now=20Available=21?=
#   From: REDMAGIC Team <news@redmagic.gg>
#   Saved email to data\email_4957.txt
# Processing email 4958...
#   Subject: Your job application is incomplete!
#   From: "Iridium Satellite @ icims" <iridium+autoreply@talent.icims.com>
#   Saved email to data\email_4958.txt
# Processing email 4959...
#   Subject: mukesh.gutkawala, see what's been happening on Instagram
#   From: "mooohhhhiiittt on Instagram" <no-reply@mail.instagram.com>
#   Saved email to data\email_4959.txt
# Processing email 4960...
#   Subject: =?utf-8?B?TmV3IHRyZWF0bWVudCB0aW1lcyBhcmUgYXZhaWxhYmxlISDwn5iy?=
#   From: "Hand and Stone Massage and Facial Spa" <noreply@email.handandstone.com>
#   Saved email to data\email_4960.txt
# Processed 4960/5000 emails.
# Processing email 4961...
#   Subject: Your package is set to arrive tomorrow!
#   From: "Jockey" <notifications@jockey.narvar.com>
#   Saved email to data\email_4961.txt
# Processing email 4962...
#   Subject: =?UTF-8?B?SnVzdCBmb3IgeW91OiDigJxUaGFsYWl2ZXR0?=
#  =?UTF-8?B?aXlhYW4gUGFhbGF5YW3igJ0gU2Vhc29uIDEg?=
#   From: Prime Video <no-reply@primevideo.com>
#   Saved email to data\email_4962.txt
# Processing email 4963...
#   Subject: Important: Last Details for Grad Fair
#   From: College of Graduate Studies <explore-gradstudies@sjsu.edu>
#   Saved email to data\email_4963.txt
# Processing email 4964...
#   Subject: Tick mark your bucket list with a Personal Loan on ICICI Bank Credit Card
#   From: "ICICI Bank" <services@custcomm.icicibank.com>
#   Saved email to data\email_4964.txt
# Processing email 4965...
#   Subject: No matter your type
#   From: Camille Rose <digital@camillerose.com>
#   Saved email to data\email_4965.txt
# Processing email 4966...
#   Subject: GS downgrades Indian stocks | Broader mkt feels Covid deja vu | T+0
#  a minus for brokers on D-Day
#   From: ET Markets Morning <newsletter@economictimesnews.com>
#   Saved email to data\email_4966.txt
# Processing email 4967...
#   Subject: September 2024
#   From: Microsoft via LinkedIn <newsletters-noreply@linkedin.com>
#   Saved email to data\email_4967.txt
# Processing email 4968...
#   Subject: =?UTF-8?Q?Reminder:_2025_Deadlines_Are_Here!=E2=8F=B0?=
#   From: Yocket Premium <hello@yocket.in>
#   Saved email to data\email_4968.txt
# Processing email 4969...
#   Subject: A shift is up for grabs
#   From: 7shifts Scheduling <notifications@7shifts.com>
#   Saved email to data\email_4969.txt
# Processing email 4970...
#   Subject: A shift is up for grabs
#   From: 7shifts Scheduling <notifications@7shifts.com>
#   Saved email to data\email_4970.txt
# Processed 4970/5000 emails.
# Processing email 4971...
#   Subject: Here's 2 FREE weeks of Uber One
#   From: Uber Eats <noreply@uber.com>
#   Saved email to data\email_4971.txt
# Processing email 4972...
#   Subject: This SBI Card OFFER expires on 30/09/2024.
#   From: Team BankBazaar <creditcard+ratealert@bankbazaar.com>
#   Saved email to data\email_4972.txt
# Processing email 4973...
#   Subject: =?utf-8?B?8J+ZjCBCdXkgb25lIEZvb3Rsb25nLCBnZXQgb25lIGZyZWUgJg==?=
#  =?utf-8?B?IHN0ZXAgdXAgdG8gYSBuZXcgZmF2ZQ==?=
#   From: "SUBWAY Restaurants" <news@subs.subway.com>
#   Saved email to data\email_4973.txt
# Processing email 4974...
#   Subject: Somesh Pushpkumar, good news: We have the perfect cash back card for you!
#   From: "Experian" <support@e.usa.experian.com>
#   Saved email to data\email_4974.txt
# Processing email 4975...
#   Subject: Your balance is below $500.00 for account ending in (...6029)
#   From: Chase <no.reply.alerts@chase.com>
#   Saved email to data\email_4975.txt
# Processing email 4976...
#   Subject: =?UTF-8?B?SnVuIFpTIHNlbnQgYSBt?=
#  =?UTF-8?B?ZXNzYWdlIHRvIHRoZSBn?=
#  =?UTF-8?B?cm91cCBjb252ZXJzYXRp?=
#  =?UTF-8?B?b24gIkp1biBaUyDCtyBMIA==?=
#  =?UTF-8?B?U2hhcGVkIElrZWEgVGFi?=
#  =?UTF-8?B?bGUgfHwgNjAkIi4=?=
#   From: "Jun via Messenger" <messages@facebookmail.com>
#   Saved email to data\email_4976.txt
# Processing email 4977...
#   Subject: Your IndusInd credit card rewards can be =?UTF-8?B?Mljwn5KO?=
#   From: INDIE by IndusInd Bank <support.indie@indusind.com>
#   Saved email to data\email_4977.txt
# Processing email 4978...
#   Subject: =?UTF-8?Q?=E2=AC=87=EF=B8=8FThis_Deal_Will_Take_You_to=E2=80=A6?=
#   From: MakeMyTrip <noreply@zen-makemytrip.com>
#   Saved email to data\email_4978.txt
# Processing email 4979...
#   Subject: =?UTF-8?Q?=E2=80=9Csoftware_engineer=E2=80=9D:_Inizio_Partners_-_?=
#  =?UTF-8?Q?Machine_Learning_Engineer_(GCP)_and_more?=
#   From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
#   Saved email to data\email_4979.txt
# Processing email 4980...
#   Subject: Tuesday Drops: Free taco every Taco Tuesday
#   From: Taco Bell Rewards <bellbuzz@email.tacobell.com>
#   Saved email to data\email_4980.txt
# Processed 4980/5000 emails.
# Processing email 4981...
#   Subject: We found something you might like
#   From: "Amazon.com" <store-news@amazon.com>
#   Saved email to data\email_4981.txt
# Processing email 4982...
#   Subject: Celebrate International Sign Language Day with Yunikee
#   From: Infosys Springboard <springboard@infosys.com>
#   Saved email to data\email_4982.txt
# Processing email 4983...
#   Subject: =?UTF-8?Q?Rs_1.8L_cr_lost_in_F&O_frenzy_|_D-St_at_ne?=
#  =?UTF-8?Q?w_peak_|_Radhika_Gupta_on_=E2=80=98dal_chawal=E2=80=99_MFs?=
#   From: ET Markets <newsletter@economictimesnews.com>
#   Saved email to data\email_4983.txt
# Processing email 4984...
#   Subject: Flash Sale: Take 20% off Sonicare DiamondClean toothbrushes
#   From: "Philips" <info@amer.ph.mc.philips.com>
#   Saved email to data\email_4984.txt
# Processing email 4985...
#   Subject: Your upcoming Investments
#   From: Paytm Money <alerts@paytmmoney.com>
#   Saved email to data\email_4985.txt
# Processing email 4986...
#   Subject: =?UTF-8?Q?=E2=80=9Ccomputer_vision_engineer=E2=80=9D:_Amaz?=
#  =?UTF-8?Q?on_Web_Services_(AWS)_-_Computer_?=
#  =?UTF-8?Q?Vision_&_ML_Engineer,_Computer_V?=
#  =?UTF-8?Q?ision_and_Remote_Sensing_and_more?=
#   From: LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
#   Saved email to data\email_4986.txt
# Processing email 4987...
#   Subject: =?UTF-8?Q?Get_zero_trading_fees_on_your_next_trade_=E2=80=94_on_us!?=
#   From: Coinbase <info@mail.coinbase.com>
#   Saved email to data\email_4987.txt
# Processing email 4988...
#   Subject: Step Up Your Hair Game, Fellas!
#   From: Camille Rose <digital@camillerose.com>
#   Saved email to data\email_4988.txt
# Processing email 4989...
#   Subject: =?UTF-8?B?RS1zdGF0ZW1lbnQ6IFlvdSBoYXZlIDUyICBQb2ludHMgd29ydGggUnMuMTMgYXMgb24gMzEsQXVndXN0IDIwMjQ=?=
#   From: =?UTF-8?B?U0JJIFJld2FyZHo=?= <noreply@alerts.sbi.co.in>
#   Saved email to data\email_4989.txt
# Processing email 4990...
#   Subject: =?UTF-8?Q?REVEALED:_Award-winning_Properties_=F0=9F=8F=86?=
#   From: MakeMyTrip <noreply@zen-makemytrip.com>
#   Saved email to data\email_4990.txt
# Processed 4990/5000 emails.
# Processing email 4991...
#   Subject: Reminder: Activate 5% to get the most out of Cashback Match
#   From: =?UTF-8?B?RGlzY292ZXIgQ2FyZA==?= <discover@card-e.em.discover.com>
#   Saved email to data\email_4991.txt
# Processing email 4992...
#   Subject: SOFT ROOTS Plant Basket
#   From: "Amazon.in" <store-news@amazon.in>
#   Saved email to data\email_4992.txt
# Processing email 4993...
#   Subject: The crypto market is crazy UP =?UTF-8?B?8J+agA==?=
#   From: CoinSwitch <no-reply@coinswitch.co>
#   Saved email to data\email_4993.txt
# Processing email 4994...
#   Subject: Hi, google, we saved it
#   From: AliExpress <ae-market.promotion00@mail.aliexpress.com>
#   Saved email to data\email_4994.txt
# Processing email 4995...
#   Subject: Somesh, you have new application updates this week
#   From: LinkedIn <jobs-noreply@linkedin.com>
#   Saved email to data\email_4995.txt
# Processing email 4996...
#   Subject: 'Poker' (USD12.00) updated by Vaibhav S.
#   From: Splitwise <hello@splitwise.com>
#   Saved email to data\email_4996.txt
# Processing email 4997...
#   Subject: Do not fall prey to investment scams!
#   From: "ICICI Bank" <services@custcomm.icicibank.com>
#   Saved email to data\email_4997.txt
# Processing email 4998...
#   Subject: =?UTF-8?B?8J+OiQ==?= New arrivals alert!
#   From: Jockey <shopjockey@email.jockeycomfort.com>
#   Saved email to data\email_4998.txt
# Processing email 4999...
#   Subject: Last 2 days left to make your corporate dream a reality- Register for
#  TCS iON NQT now
#   From: TCS iON <info.tcsionhub@tcsion.com>
#   Saved email to data\email_4999.txt
# Processing email 5000...
#   Subject: What does it mean to activate your membership?
#   From: "Aleyah Thomas-Bowman" <StudentWorkers@csueu.org>
#   Saved email to data\email_5000.txt
# Processed 5000/5000 emails.
# Successfully processed and saved 5000 emails.
